# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/Program Skripsi/Dataset/training.csv', delimiter = ";", index_col = 0)
test = pd.read_csv('/content/drive/MyDrive/Program Skripsi/Dataset/testing.csv', delimiter = ";", index_col = 0)

# %%
test = test.set_axis(['Temp_min', 'Temp_max', 'Temp_avg', 'Kel_avg','Curah_hujan','Lama_sun','Kec_angin_max','Arah_angin_max','Kec_angin_avg','Angin_byk'], axis=1, inplace=False)
train = train.set_axis(['Temp_min', 'Temp_max', 'Temp_avg', 'Kel_avg','Curah_hujan','Lama_sun','Kec_angin_max','Arah_angin_max','Kec_angin_avg','Angin_byk'], axis=1, inplace=False)

# %%
test['Curah_hujan'] = test['Curah_hujan'].replace(8888.0, 0)

# %%
train['Curah_hujan'] = train['Curah_hujan'].replace(8888.0, 0)

# %%
test = test.fillna(test.mean())
test
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#             Temp_min  Temp_max  Temp_avg  Kel_avg  Curah_hujan  Lama_sun  \
# Tanggal
# 01-01-2021      21.3      28.4      22.8     92.0         28.0       4.4
# 02-01-2021      21.6      26.4      23.7     88.0         21.3       2.2
# 03-01-2021      20.8      28.1      24.2     86.0          1.5       0.8
# 04-01-2021      21.2      27.2      23.1     90.0          0.6       2.4
# 05-01-2021      20.4      26.8      23.1     90.0         55.3       0.1
# ...              ...       ...       ...      ...          ...       ...
# 21-12-2021      21.0      28.6      24.4     82.0         22.6       4.3
# 22-12-2021      20.8      29.4      24.5     85.0          0.5       1.4
# 23-12-2021      21.5      29.8      24.1     85.0          0.0       4.8
# 24-12-2021      20.8      30.6      23.4     83.0         13.0       3.2
# 25-12-2021      20.4      28.5      24.4     83.0          7.0       5.8
#
#             Kec_angin_max  Arah_angin_max  Kec_angin_avg Angin_byk
# Tanggal
# 01-01-2021              3             150              1         C
# 02-01-2021              4             110              2         C
# 03-01-2021              5             120              2        SE
# 04-01-2021              4             120              1         C
# 05-01-2021              2             150              1         C
# ...                   ...             ...            ...       ...
# 21-12-2021              6              60              2        NE
# 22-12-2021              4              50              2         C
# 23-12-2021              4             160              1         C
# 24-12-2021              5             120              1         C
# 25-12-2021              3             280              1         C
#
# [359 rows x 10 columns]

# %%
train = train.fillna(train.mean())
train

# %%
import seaborn as sns
import matplotlib.pyplot as plt
kor_train = train.corr()
sns.heatmap(kor_train,annot = True,fmt=".2g",cmap='RdYlGn')
plt.show()

# %%
columns = ['Temp_min', 'Temp_max', 'Temp_avg', 'Kel_avg','Curah_hujan','Kec_angin_max','Arah_angin_max']
train = pd.DataFrame(train, columns=columns)
test = pd.DataFrame(test, columns=columns)

# %%
train.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fca61620790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fca615ad190>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fca61645150>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fca69f720d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fca61628cd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fca6158dfd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fca615db410>],
#       dtype=object)

# %%
test.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebfc16890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebfbd79d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebe389d10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebe335b90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebe3073d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebe2be710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ebe276ad0>],
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#scaler = StandardScaler()
# fit and transform in one step
df = scaler.fit_transform(train)
df2 = scaler.fit_transform(test)
df = pd.DataFrame(df)
df2 = pd.DataFrame(df2)

# %%
y_train = df[4]  # dependent or target 
x_train = df.drop([4],axis = 1)  # indepedent or input
y_test = df2[4]  # dependent or target 
x_test = df2.drop([4],axis = 1)  # indepedent or input

x_train_reshape = x_train.values.reshape((x_train.shape[0], 1, x_train.shape[1]))
y_train_reshape = y_train.values.reshape((y_train.shape[0],1,1))

x_test_reshape = x_test.values.reshape((x_test.shape[0], 1, x_test.shape[1]))
y_test_reshape = y_test.values.reshape((y_test.shape[0],1,1))

# %%
from keras.layers import Dropout, Dense, LSTM
from keras.models import Sequential
model = Sequential()
#layer 1
model.add(LSTM(100,return_sequences=True, activation ='relu', input_shape =(1,x_train.shape[1])))
model.add(Dropout(0.2))

#layer 2
model.add(LSTM(100,activation ='relu',return_sequences=True,))
model.add(Dropout(0.2))

#layer 3
model.add(LSTM(100,activation ='relu',return_sequences=True,))
model.add(Dropout(0.2))

#layer 4
model.add(LSTM(100,activation ='relu'))
model.add(Dropout(0.2))

model.add(Dense(units =1, activation='relu'))
# Out:
#   File "<ipython-input-1-251420ee7e1f>", line 5
#     model.add(layers.Dense(10, activation='softmax'))model.compile(optimizer='adam',
#                                                      ^
# SyntaxError: invalid syntax

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 100)            42800
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  lstm_1 (LSTM)               (None, 1, 100)            80400
#
#  dropout_1 (Dropout)         (None, 1, 100)            0
#
#  lstm_2 (LSTM)               (None, 1, 100)            80400
#
#  dropout_2 (Dropout)         (None, 1, 100)            0
#
#  lstm_3 (LSTM)               (None, 100)               80400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 284,101
# Trainable params: 284,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mean_squared_error", metrics = ['accuracy'])
history = model.fit(x_train_reshape,y_train_reshape,epochs = 10, batch_size = 64)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 6s 11ms/step - loss: 0.0140 - accuracy: 0.5431
# Epoch 2/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0136 - accuracy: 0.5431
# Epoch 3/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0132 - accuracy: 0.5431
# Epoch 4/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0126 - accuracy: 0.5431
# Epoch 5/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0124 - accuracy: 0.5431
# Epoch 6/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0125 - accuracy: 0.5431
# Epoch 7/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0124 - accuracy: 0.5431
# Epoch 8/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0124 - accuracy: 0.5431
# Epoch 9/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0125 - accuracy: 0.5431
# Epoch 10/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0124 - accuracy: 0.5431
# Epoch 11/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0124 - accuracy: 0.5431
# Epoch 12/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 13/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 14/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 15/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 16/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0123 - accuracy: 0.5431
# Epoch 17/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 18/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0123 - accuracy: 0.5431
# Epoch 19/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 20/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 21/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0120 - accuracy: 0.5431
# Epoch 22/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0122 - accuracy: 0.5431
# Epoch 23/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0121 - accuracy: 0.5431
# Epoch 24/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0120 - accuracy: 0.5431
# Epoch 25/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0120 - accuracy: 0.5431
# Epoch 26/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0120 - accuracy: 0.5431
# Epoch 27/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 28/50
# 63/63 [==============================] - 1s 12ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 29/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 30/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 31/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0120 - accuracy: 0.5431
# Epoch 32/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 33/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 34/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 35/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 36/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 37/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 38/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 39/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 40/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0120 - accuracy: 0.5431
# Epoch 41/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 42/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0117 - accuracy: 0.5431
# Epoch 43/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0119 - accuracy: 0.5431
# Epoch 44/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 45/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 46/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0117 - accuracy: 0.5431
# Epoch 47/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 48/50
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 49/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0118 - accuracy: 0.5431
# Epoch 50/50
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0117 - accuracy: 0.5431

# %%
model.save("/content/drive/MyDrive/Model/model-A1-50.h5")
print("Saved model to disk")

# %%
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss'], loc = 'upper right')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
scores = model.evaluate( x_train_reshape, y_train_reshape, verbose =0)
print("Model accuracy : %.2f%%" % (scores[1]*100))
# Out:
# Model accuracy : 54.31%

# %%
from keras.models import load_model

from keras.models import load_model
model = load_model('/content/drive/MyDrive/Model/model-A1-50.h5')

# %%
inverse_scale = MinMaxScaler()
inverse_scale.min_, inverse_scale.scale_ = scaler.min_[4], scaler.scale_[4]

predict = model.predict(x_test_reshape)
predicted = inverse_scale.inverse_transform(predict.reshape((x_test_reshape.shape[0],1)))
y_test_convert = inverse_scale.inverse_transform(y_test_reshape.reshape((y_test_reshape.shape[0],1)))

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt

mse = mean_squared_error(y_test_convert,predicted)
print ("MSE : ",mse)
rmse = sqrt(mse)
print ("RMSE : ",rmse)
mae = mean_absolute_error(y_test_convert,predicted)
print ("MAE : ",mae)
# Out:
# MSE :  200.75762729287013
# RMSE :  14.168896474068477
# MAE :  7.697809215779584

# %%
y_act = pd.DataFrame(y_test_convert)
y_act.columns = ['Actual']
y_act.index = test.index

# %%
pred = pd.DataFrame(predicted)
pred.columns = ['Prediksi']
pred.index = test.index

# %%
plt.figure(figsize=(20,5))
plt.plot(y_act, color='blue', label='Actual values')
plt.plot(pred, color='red', label='Predicted')
plt.title('Test data')
plt.xlabel('Tanggal')
plt.ylabel('Curah Hujan')
plt.legend(loc='best')
